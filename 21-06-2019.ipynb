# %%
##Anagrams

a=input()
b=input()
x1=[]
x2=[]
x=[]
Temp=ord('a')
for i in range(0,26):
    x1.append(a.count(chr(Temp)))
    x2.append(b.count(chr(Temp)))
    Temp=Temp+1
for i in range(0,26):
    x.append(abs(x1[i]-x2[i]))
print(sum(x))
# Out:
# cde
# abc
# 4

# %%
import re

def phoneNumberValidation(number):
    pattern = '^[6-9][0-9]{9}$|[0][6-9][0-9]{9}$|[+][9][1][6-9][0-9]{9}$'
    if re.match(pattern,str(number)):
        return True
    else:
        return False

#phoneNumberValidation(8106410134)

def emailValidator(email):
    pattern = "^[0-9a-z][0-9a-z-.]{4,13}[0-9a-z][@][a-z0-9]{3,18}[.][a-z]{2,4}$"
    if re.match(pattern,email):
        return True
    return False

# %%
## Function to add contact to contacts  text file
from Packages.validation import phoneNumberValidator as pnv,emailValidator as ev

# from Packages import validation
def addContact(name,phone,email):
    ## store data as name,phone,email in the contact file
    filename = 'DataFiles/contacts.txt'
    if not checkContactExists(name):
        if pnv(phone) and ev(email):
            with open(filename, 'a') as f:
                line = name +','+ str(phone) + ','+ email + '\n'
                f.write(line)
            print(name, 'added to contacts')
        else:
            print('Invalid phone number or email')
            return
    else:
        print(name, 'already exists')
    return
# addContact("name1",3457349533,"name1_123@gmail.com")


############ Function to check if contact already exists###########
def checkContactExists(name):
    filename = "DataFiles/contacts.txt"
    with open(filename, 'r') as f:
        filedata = f.read()
        pattern = name+','
    return re.search(name, filedata)

if checkContactExists("name1,"):
     print(True)
else:
    print(False)
addContact('name1', 1344563,'adf')
# Out:
# True
# name1 already exists

# %%
############ Function to check if contact already exists###########
def checkContactExists(name):
    filename = "DataFiles/contacts.txt"
    if not 
    with open(filename, 'r') as f:
        filedata = f.read()
        pattern = name+','
    return re.search(name, filedata)

if checkContactExists("name1,"):
    print(True)
else:
    print(False)
# Out:
# True

# %%
## Enter contacts into a lsit like [[],[],[]]

filename = 'DataFiles/contacts.txt'
def csvToList(filename):
    li =[]
    with open(filename, 'r') as f:
        for line in f:
            li.append(line.split(','))
    return li

# csvToList(li)
def listToFile(li):
    s= ''
    for i in li:
        s=s+s.join(i)
    return s
li = csvToList(filename)
listToFile(li)
# Out:
# 'name13457349533name1_123@gmail.com\nname1name13457349533name1_123@gmail.com\n3457349533name13457349533name1_123@gmail.com\nname1_123@gmail.com\nname1name13457349533name1_123@gmail.com\nname1name13457349533name1_123@gmail.com\n3457349533name13457349533name1_123@gmail.com\nname1_123@gmail.com\n3457349533name13457349533name1_123@gmail.com\nname1name13457349533name1_123@gmail.com\n3457349533name13457349533name1_123@gmail.com\nname1_123@gmail.com\nname1_123@gmail.com\nname1name13457349533name1_123@gmail.com\nname1name13457349533name1_123@gmail.com\n3457349533name13457349533name1_123@gmail.com\nname1_123@gmail.com\nname1name13457349533name1_123@gmail.com\nname1name13457349533name1_123@gmail.com\n3457349533name13457349533name1_123@gmail.com\nname1_123@gmail.com\n3457349533name13457349533name1_123@gmail.com\nname1name13457349533name1_123@gmail.com\n3457349533name13457349533name1_123@gmail.com\nname1_123@gmail.com\nname1_123@gmail.com\n3457349533name13457349533name1_123@gmail.com\nname1name1
# ...
